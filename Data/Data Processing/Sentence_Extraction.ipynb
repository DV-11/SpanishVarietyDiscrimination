# %%
import pandas as pd
import re

# %%
# !git clone https://github.com/DV-11/SpanishDialectDiscrimination.git
# Out:
# Cloning into 'SpanishDialectDiscrimination'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 23 (delta 3), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 10.98 MiB | 5.50 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %% [markdown]
# # Loading the data

# %%
preseea_df = pd.read_csv('/content/SpanishDialectDiscrimination/Data/PRESEEA.csv')

# %%
preseea_es = preseea_df[preseea_df['country'] == 'España'].reset_index()['text']
preseea_mx = preseea_df[preseea_df['country'] == 'México'].reset_index()['text']

# %%
print("Numer of PS dialogues: ", len(preseea_es))
print("Numer of MS dialogues: ", len(preseea_mx))
# Out:
# Numer of PS dialogues:  233
# Numer of MS dialogues:  90

# %% [markdown]
# Find specific entry index by text ID

# %%
text_id = 'MADR_H11_002'
dataset = preseea_es

dataset.str.contains(text_id).idxmax()
# Out:
# 36

# %% [markdown]
# # Parsing dialogue

# %%
# es - 37 ; mx - 19
dialogue = preseea_mx[19]

# %%
split_str = dialogue.split('</Trans>')
info = split_str[0]
transcript = split_str[1]

# %%
all = re.findall(r'(E:|I:)(.*?)(?=(?:E:|I:)|$)', transcript)

dialogue_lines = []
current_line = {'E_line': None, 'I_line': None}

for i, j in all:
    stripped_line = j.strip().removesuffix('/').strip()

    if i == 'E:':
        if current_line['I_line'] is not None:
            dialogue_lines.append(current_line)
            current_line = {'E_line': None, 'I_line': None}
        current_line['E_line'] = stripped_line
    elif i == 'I:':
        current_line['I_line'] = stripped_line

    if current_line['E_line'] is not None and current_line['I_line'] is not None:
        dialogue_lines.append(current_line)
        current_line = {'E_line': None, 'I_line': None}

if current_line['E_line'] is not None or current_line['I_line'] is not None:
    dialogue_lines.append(current_line)

# %%
dialogue_df = pd.DataFrame(dialogue_lines)
dialogue_df['Line_number'] = dialogue_df.index + 1
dialogue_df = dialogue_df[['Line_number', 'E_line', 'I_line']]

dialogue_df.head()
# Out:
#    Line_number                                             E_line  \
# 0            1                          ¿cómo empezaste a bailar?
# 1            2                                                ¿y?
# 2            3  <simultáneo> pero porque </simultáneo> es exte...
# 3            4  <simultáneo> ¿pero es </simultáneo> externa na...
# 4            5                                                 mh
#
#                                               I_line
# 0  <tiempo = "00:02"/> ¿cómo empecé a bailar? // ...
# 1     y pues es / <simultáneo> fue eso </simultáneo>
# 2  porque es externa <simultáneo> porque </simult...
# 3  sí / porque / y ya / bueno ya / de ahí / no me...
# 4  y ya de ahí pues / conocí la danza / en lo que...

# %% [markdown]
# Clean up unnecessary tags

# %%
dialogue_df['E_line'] = dialogue_df['E_line'].str.replace('<alargamiento/>','')
dialogue_df['E_line'] = dialogue_df['E_line'].str.replace('<vacilación/>','')
dialogue_df['E_line'] = dialogue_df['E_line'].str.replace('</simultáneo>','')
dialogue_df['E_line'] = dialogue_df['E_line'].str.replace('<simultáneo>','')

# %%
dialogue_df['I_line'] = dialogue_df['I_line'].str.replace('<alargamiento/>','')
dialogue_df['I_line'] = dialogue_df['I_line'].str.replace('<vacilación/>','')
dialogue_df['I_line'] = dialogue_df['I_line'].str.replace('</simultáneo>','')
dialogue_df['I_line'] = dialogue_df['I_line'].str.replace('<simultáneo>','')

# %% [markdown]
# # Dialogue Info

# %%
tags = [i for i in info.split(' ') if '=' in i]

all_info = {}

for i in tags:
  split_tag = i.split('=')
  k = split_tag[0]
  v = split_tag[1]

  if not re.findall('"([^"]*)"',split_tag[1]):
    all_info[split_tag[0]] = None
  else:
    all_info[split_tag[0]] = re.findall('"([^"]*)"',split_tag[1])[0]

important_keys = ['audio_filename','clave_texto', 'pais', 'fecha_grab', 'fecha_trans']

dialogue_info = {key: all_info[key] for key in important_keys}

# %%
info
# Out:
# '<Trans audio_filename="MEXI_H12_042.wav" xml:lang="español"> <Datos clave_texto="MEXI_H12_042" tipo_texto="entrevista_semidirigida"> <Corpus corpus="PRESEEA" subcorpus="PRESEEA_MÉXICO" ciudad="México, D. F." pais="México"/>  <Grabacion resp_grab="Alejandra Aide Espinoza Vázquez" lugar="Escuela Nacional de Danza Folclórica" duración="90\'" fecha_grab="2006-04-17" sistema="DAT"/> <Transcripcion resp_trans="J. Rodríguez" fecha_trans="2006-07-07" numero_palabras="15541"/> <Revision num_rev="1" resp_rev="A. Salas" fecha_rev="2006-12-11"/> <Revision num_rev="2" resp_rev="T. García Torres" fecha_rev="2007-02-28"/> <Revision num_rev="3" resp_rev="L. Roldán" fecha_rev="2007-04-03"/> <Revision num_rev="4" resp_rev="P. Martín" fecha_rev="2010-07-31"/> <Revision num_rev="5" resp_rev="P. Ledesma" fecha_rev="2017-05-05"/></Datos>  <Hablantes> <Hablante id="hab1" nombre=" MEXI_H12_042" código_hab="I" sexo="hombre" Grupo_edad="1" edad="20" nivel_edu="medio" estudios="bachillerato" profesión="estudiante" origen="Distrito Federal" papel="informante"/> <Hablante id="hab2" nombre="Alejandra Aide Espinoza Vázquez" código_hab="E" sexo="mujer" grupo_edad="1" edad="24" nivel_edu="alto" estudios="linguistica" profesión="estudiante" origen="Estado de México" papel="entrevistador"/>  <Relaciones rel_ent_inf = "ninguna" rel_inf_aud ="no"rel_ent_aud="no"/> </Hablantes> '

# %%
dialogue_info
# Out:
# {'audio_filename': 'MEXI_H12_042.wav',
#  'clave_texto': 'MEXI_H12_042',
#  'pais': 'México',
#  'fecha_grab': '2006-04-17',
#  'fecha_trans': '2006-07-07'}

# %% [markdown]
# # Readable transcript

# %%
for i in dialogue_df.iterrows():
  print(i[1].Line_number, 'E:', i[1].E_line)
  print(i[1].Line_number, 'I:', i[1].I_line)
  print('')
# Out:
# 1 E: ¿cómo empezaste a bailar?
# 1 I: <tiempo = "00:02"/> ¿cómo empecé a bailar? // fue bien / bueno / fue chistoso porque este / empecé con un profesor / que montaba puros quince años // y ya de ahí me invitó a salir en quince años / y ya ves / ahí vas de metiche / pero para esto // yo lo conocí a él porque  en la secundaria / una de mis mejores amigas / me pidió que fuera su chambelán / le dije que sí / entonces ya ahí conocí a él / y de ahí / de ahí este / se llama J G // me empezó a jalar a / a montar quince años / y me pagaba y ya yo estaba con él / y de repente <ininteligible/> él / él baila folclor y se le ocurrió formar su grupo folclórico // entonces yo fui uno de los que empezó con su ballet de él / y yo / ahí / netamente el folclor / ahí lo conocí // y ya de ahí em <palabra_cortada/> / pues me empezó a gustar mucho y / y le empecé a echar ganas y em <palabra_cortada/> / empecé a bailar / un poquito mejor / y ya de repente / pues / él me comentó de la escuela / entonces ya este / empec <palabra_cortada/> / empecé a / hacer el trámite para hacer el examen de admisión / y lo hice jun <palabra_cortada/> / junto con otro compañero de ahí / que se llama C / <ruido = "carraspeo"/> / y ya este / venimos </sic> a hacer el examen los dos juntos / pero él se quedó / y yo / a mí me rechazaron / porque dijeron que no había pasado el examen psicológico y el examen médico // que el psicológico me dijeron que tenía desorden mental <risas = "I"/> / o cosas así / y este // y el médico pues porque tengo la malformación en mi oído
#
# 2 E: ¿y?
# 2 I: y pues es /  fue eso
#
# 3 E:  pero porque  es externa / ¿no?
# 3 I: porque es externa  porque
#
# 4 E:  ¿pero es  externa nada más?
# 4 I: sí / porque / y ya / bueno ya / de ahí / no me aceptaron por eso / hice un relajo y ya total que no me quedé // y ya yo seguí bailando / me metí a otro ballet / ya un poco más profesional / que se llama el B F / el M
#
# 5 E: mh
# 5 I: y ya de ahí pues / conocí la danza / en lo que es la estética de / de un / de / lo que es la tradición / o sea muy estilizado / <ruido = "carraspeo"/> y este / y ahí duré // casi medio año // entonces ya // eh / y / después de ese medio año / me <palabra_cortada/> empecé a tomar cursos / así / que daban en / centros comunitarios / y cosas de esas // y / y se <ininteligible/> volvió a abrir la convocatoria de la escuela
#
# 6 E:  y lo volviste a hacer
# 6 I:  entonces ya  / volví a hacer el examen
#
# 7 E: ajá
# 7 I: pero para poder hacerlo // como ya había tenido el antecedente de que este
#
# 8 E: ¿habías sido rechazado?
# 8 I: ajá
#
# 9 E: ajá
# 9 I: pues tuve que hacer varias pruebas psico <palabra_cortada/> // de / para mi oído / pero no me acuerdo de la disciplina / creo que era / otorrinolaringólogo
#
# 10 E: ajá
# 10 I: entonces me pidieron una responsiva / y una audiometría / y varios estudios médicos /  y sí
#
# 11 E: <tiempo = "02:31"/>  para  ver que estuvieras bien
# 11 I: ajá y sí / me llevé un buen varo en eso / entonces ya / hice eso / y yo hablé con G / la psicóloga / y pues le dije que me ayudara a pasar el / el psicosométrico / y ya / me dijo que este / que no estaba tan mal / pero que tenía una / una autoestima muy baja // y ya / pues total / que ya hice el examen y me quedé <ruido = "palmada"/> / y aquí he es <palabra_cortada/> / pues he estado hasta los tres años de / la carrera / pero pues / ya voy a salir / en este semestre
#
# 12 E: ¿pero y luego? / este // qué / más argumentos te / o sea sí / tenías la autoestima baja / ¿y?
# 12 I: pues nada más fue eso / y / lo que pesó mucho fue el examen de // el médico // porque yo / cuando vine a hablar de eso // hablé de / de / cómo había estado en el examen de danza / y de aptitudes / y cosas de esas // y A M / que dicen que era el más / sangrón para calificar / que / me había puesto diez / y que / no tenía problemas para entrar a la escuela como bailarín / pero lo que / influyó mucho / fue el médico / y el psicológico
#
# 13 E: <ininteligible/>
# 13 I: entonces ya / pues ya / ya no me quedé / ese año lo perdí / pero pues / conocí a mucha gente / mucho / en el gremio de la danza / pues / me abrí mucho porque / aparte del / del ballet que estuve <ininteligible/> / y todos los cursos / conocí a mucha / mucha gente / que sí me / echaron la mano / y me dijeron / <cita> no / pues que / estás bien / pero te falta esto y </cita> / y pues sí / me enseñaron / muchísimas más cosas del / primer ballet donde yo estuve porque / en realidad el ballet donde / empecé / pues era un ballet así como que
#
# 14 E: equis
# 14 I: equis / no muy / no muy reconocido / y hasta la fecha / ¿eh? / porque / ya con cinco años que tiene el grupo / pues no / nada más no / no dan una // y el maestro pues / no creo que tenga un título / cosas así / ha sido / pues / por lo que él ha / le han enseñado pero / no es bueno el ballet / entonces // yo sí / carecía de demasiadas cosas / en cuanto a bailarín / y pues / pues ya con el ballet que estuve y todo lo demás / pues //  sí
#
# 15 E:  ya está  / ¿y ahorita cómo te sientes?
# 15 I: mm / ¿en qué sentido? /  ¿cómo bailarín?
#
# 16 E:  este / ajá  / exacto
# 16 I: pues siento que / que sí me hacen falta muchas cosas // yo creo que la primera de todas sería una buena // interpretación / porque / no tengo mala técnica / tengo // tengo altura / tengo / estética / pero / me hace falta creérmela más <risas = "I"/> / creer más que soy un bailarín // pero creo que sería lo único
#
# 17 E: ¿y limpieza de pasos? /  ¿sí?
# 17 I:  pues  hasta eso / no es <palabra_cortada/> / no estoy tan / tan / tirado a la basura / pero sí / sí me hace falta / obviamente / pues / con el / con la práctica de la escuela / y las / las clases que he tomado / pues me ha ayudado mucho a / limpiar todo eso
#
# 18 E: <tiempo = "05:06"/> oye / ¿y qué / qué vas a hacer después?
# 18 I: qué voy a hacer
#
# 19 E: pues ya sales en
# 19 I: <ruido = "carraspeo"/>
#
# 20 E: ya
# 20 I: mh // pues / fíjate que ha sido muy // muy difícil pensarlo porque yo quería ser médico antes de ser bailarín // entonces / yo estaba // estudiando / antes de entrar a la escuela / yo estaba estudiando un / un / bachillerato en / ciencias biológicas para poder ser médico // entonces / como me salí <ininteligible/> / que el / momento en el que yo <ininteligible/> / decidí hacer mi primer examen para entrar / me salí de esa escuela // e  era este/ el <siglas = [se.se.hache]> C C H </siglas> // entonces ya me salí de la escuela / y llegué a aquí / y de resultas que no me quedé / entonces ¡perdí dos años! / ahí de estudio ya al / tirados a la basura
#
# 21 E: o sea / ya / ¿ya ibas en cuarto semestre?
# 21 I: no / iba / iba en segundo
#
# 22 E:  semestre
# 22 I:  pero  como me salí
#
# 23 E: ¡ah / claro!
# 23 I: pues ya todo
#
# 24 E: sí / uno / dos /  ajá
# 24 I:  ajá  / eran dos años // entonces / pues ya / perdí ese año y / ya total que me metí aquí / y aquí estudio el bachillerato también / pero pues es en ciencias y humanidades / entonces ya estuve investigando para la carrera que quería / de médico / cirujano / y este / y pues obviamente te piden un bachillerato con / ciencias biológicas / y ya no voy a poder mi / hacer mi examen a la Unam // porque / el pase automático del <siglas = [se.se.hache]> C C H </siglas>/  pues ya
#
# 25 E:  lo perdiste
# 25 I: ya lo perdí / y pues otra / otra de las cosas que me gusta mucho / es la economía pero / pero la verdad no me veo estudiando en una universidad algo que no me gusta / entonces // no / de plano yo creo que me <risas = "I"/> voy a dedicar mejor a la danza y / y / con esto de que se acaba de abrir la licenciatura aquí / pues / yo creo que me voy a venir otros cuatro años a enclaustrarme aquí
#
# 26 E: <risas = "E"/>
# 26 I: y sacar la licenciatura // porque te juro que ahorita ya a estas alturas de la carrera yo ya no quiero venir / ya / ya los / mae stros / las clases / los alumnos / ya todo está muy mal / ya / ni / por parte de ellos / de los profesores / ni de nosotros / porque pues ellos / como tienen / problemas con los directivos / pues no / y ya / están a punto de jubilarse / pues ya están / también ellos en las últimas / ya lo que quieren es salir
#
# 27 E: sí / les tocó un mal  momento
# 27 I:  <ruido = "carraspeo"/>  ajá / sí / un muy muy mal momento
#
# 28 E: pero ¿qué / qué tipo de conflicto? / o sea / que / entre ustedes // maestros / alumnos / ¿ qué tipo de ?
# 28 I:  maestros alumnos  / yo vería que / al menos a mí no me inspiran nada / ni siquiera para / una / cómo te diré / como una / aspiración a ser como ellos en cuestión de / bailarín o / o de conocedor de la danza // no me inspiran nada de eso / yo creo que nosotros menos a ellos / no les inspiramos e  / que ellos nos enseñen / como que es recíproco ahí la cosa / entonces ya se jodió el asunto  <risas = "I"/>
#
# 29 E: <tiempo = "07:45"/>  <risas = "E"/>
# 29 I: y es bien chistoso porque // un ejemplo muy claro es A P / A P ya no nos quiere dar clase / ya / sus / su
#
# 30 E: ¡pero él es / él es de los más jóvenes!
# 30 I: sí / y fíjate / y nos da repertorio / y es / y es un excelente profesor pero // pues no / vamos atrasados en el repertorio / las secuencias muy sencillas / y él dice que nosotros tenemos un mal zapateado / una mala retención / una mala postura / una mala // este / alineación del cuerpo / y todas esas cosas que él nos dice que nosotros / pues ya nada más de ver que hace lo mismo / pues ya te / empiezas a estar marcando y otra vez lo mismo y lo mismo y lo mismo / y no pasa de sus líneas / y cosas de esas / que yo ya estoy harto de esa clase con él / y otra / pues / por ejemplo / la maestra / I / que nos da / análisis del movimiento // no / composición coreográfica
#
# 31 E: ah
# 31 I: este <ruido = "carraspeo"/> // pues no sabe / no tiene temática de clase> / no tiene una organización en / su forma de <ininteligible/> / de dar clases / se contradice en lo que / en lo que explica / no / no // si no le entiendes / te dice / <cita> pues ahí hazle como tú quieras </cita> / y no te explica y no va más allá / y cuando / te pones en contra del punto que ella está defendiendo // no te lo acepta / y a <palabra_cortada/> y así tú le des argumentos / no / nomás no / te dice que no / que está mal / y
#
# 32 E: ¿pero siempre fue ella?
# 32 I: no
#
# 33 E: D / primero
# 33 I: D / primero / D era muy buena / cuando yo / estaba en  / tercer semestre / me dio / ah no / fue en cuarto / D me dio en cuarto / y era muy muy buena / pues a mí me / me gustaba mucho sus clases de ella / pero ya después ya pasé a quinto y a sexto / y me tocó con esta J
#
# 34 E:  mm
# 34 I:  y ya  / y ya no no / no y no
#
# 35 E:  híjole
# 35 I:  pero pues  / e <palabra_cortada/> en otras materias pues yo creo que // que sí  / más o menos ahí / la vamos llevando / la / el que sí / de plano / ya estoy harto es / es de este M
#
# 36 E: <risas = "E"/> ¿por qué?
# 36 I: de plano  M no
#
# 37 E:  ¿cuál es  toda esa bronca? / ¿eh? / que traen / no el / bueno // yo sí lo conozco pero en  otro / pues no es mi maestro / ¿no? / nunca fue mi maestro
# 37 I: ajá
#
# 38 E: pero / ¿por qué?
# 38 I:  ¿con M?
#
# 39 E:  ¿qué onda?  / ajá
# 39 I: pues lo que pasa es que M / no sabe ser profesor // no / no tiene pedagogía para dar clases // entonces / hay formas de / en las que explica / y en / su forma de / de dar a entender los conceptos que / tiene su clase / y su clase / entre comillas porque // de plano / ni siquiera en el contenido de / de lo que es el área de música / etno <palabra_cortada/> etnomúsica que es la materia // pues nos enseña cosas que / ni siquiera <ininteligible/> / a mí / a mí por ejemplo / para qué me sirve saber <ininteligible/> / afinar una / vihuela o / una jarana o / o un re <palabra_cortada/> / una / huapanguera / pues yo no voy a ser músico // a mí me gustaría más conocer / pues // música de los pueblos / o cosas de esas / pues yo me imagino que eso es la / etnomúsica / ¿no?
#
# 40 E: <tiempo = "10:29"/> mh
# 40 I: no sé / la verdad / pues / con él de plano // y en cuestión de instrumentos pues sí / pues e <palabra_cortada/> / él es músico / sabe enseñar // pues hasta ahí se queda en eso / no da más allá
#
# 41 E:  ah
# 41 I:  y <ininteligible/>  / y ahorita por ejemplo // me comentaban que ha cambiado mucho / porque antes era pésimo <risas = "I"/> / antes era peor / y luego / como no tiene didáctica de clase / pues / te duermes // y como / los temas son tan // a mí la verdad no me interesa lo que nos / nos está enseñando / pues / yo no entro o cosas así
#
# 42 E: <risas = "E"/>
# 42 I: pero pues así es M
#
# 43 E: ¡ups! / qué mal / oye / ¿y tú familia qué dice? / de
# 43 I: mi familia / pues / pero qué dicen / ¿respecto a qué?
#
# 44 E: pues así / que eres bailarín /  después de que querías ser médico
# 44 I:  ah / de que eres bailarín / huy <risas = "I"/>  / no / fue el acabóse / porque cuando <ruido = "carraspeo"/> // primero cu <palabra_cortada/> ah / en el momento que decidí dejar el <siglas = [se.se.hache]> C C H </siglas>/ pues mi papá // puso el grito en el cielo / ¿no? / y a <palabra_cortada/> / y bueno y él / y ya en ese tiempo / pues ya mis papás estaban separados / pero pues yo sigo viendo a mi papá
#
# 45 E: ah ya
# 45 I: y él es muy muy machista
#
# 46 E: <risas = "E"/>
# 46 I: entonces te imaginarás el decirle <cita> voy a dejar de / la prepa / por meterme a ser bailarín </cita> / <cita> ¿sí? / ¿y qué te pasa? / ¿dónde quedó tu hombría? </cita> / casi casi me dice
#
# 47 E: híjole / qué difícil /  ¿no?
# 47 I:  ¡ay no!  / sí / fue / con mi papá fue difícil / pero a final de cuenta / pues no me interesó él / porque pues / como no vivo con él y no aporta y no da / pues me valió su opinión // la que sí me importaba mucho era mi mamá porque / pues / con ella sí llevo una relación / súper bien // y lo que ella // espera de mí / pues yo creo que / ha sido muy / muy satisfactorio de ella / hacia conmigo / yo / creo que he sido // de / los tres hermanos que somos / incluyéndome a mí / creo que el eh / es el que he sido / más constante con ella / entonces ella sí me tiene como en un punto muy / de ahora a ver <ininteligible/> / qué hace / y no sólo mi mamá toda mi familia siempre / como que / ay no / es bien feo porque / cuando yo decidí hacer una actividad / ahí metían a todos mis primos // entonces siempre estuve rodeado de mi familia en todos los aspectos / cuando entré al primer ballet donde yo estuve / ahí metieron a todos mis primos / y ahí estuvo la / toda la familia / ya casi era el ballet de la familia I
#
# 48 E: <tiempo = "12:40"/>  <risas = "E"/>
# 48 I:  ahí estaban  todos // y cuando / ¡ah!/ pero fíjate / antes era / bien contrastante <risas = "I"/> / porque me metí a un grupo de militares /  <risas = "I"/>
#
# 49 E:  <risas = "E"/>
# 49 I: y ahí yo andaba marchando y bien / bien hombre yo <risas = "I"/> / y resulta que soy reina  <risas = "I"/>
#
# 50 E:  <risas = "E"/>
# 50 I: sí  <risas = "I"/>
#
# 51 E:  <risas = "E"/>  ¿pero cómo? / ¿y qué? / ¿y qué hacías con un grupo de militares?
# 51 I: pues fue / en la secundaria / no tenía amigos / no salía de mi casa / estaba enclaustrado / era un / un pésimo alumno porque ni siquiera me importaba la escuela // y de repente llegó un grupo de militares a la escuela / se llama P
#
# 52 E: ajá
# 52 I: y ya este / dijeron las actividades que hacían / y a mí me gustó por el / la actividad física que hacían / no por lo militar
#
# 53 E: ajá <risas = "E"/>
# 53 I: y ya cuando llego / te forman / te ponen a marchar / te ponen a / hacer tanta cosa que hacen los militares / pero me gustó / me gustó mucho esa actividad que yo hice / en aquellos tiempos / y de hecho / creo que ha sido una de las más satisfactorias de / las actividades que he hecho porque me fui a concursar nacionalmente / eh a nivel pentatlón / y aquí en el Distrito / ganamos muchas medallas y / y sí me fue muy bien en ese grupo / yo ahí / no me hubiera salido hasta que me querían enclaustrar ya en el colegio / entonces yo ya ahí / ya no quise / entonces ya me salí / y ya fue cuando empecé a bailar
#
# 54 E: <risas = "E"/>
# 54 I: y ya fue cuando entré al / al bachillerato / dejé la escuela / y le digo a mi mamá que / que voy a ser bailarín <risas = "I"/> / mi mamá pues / pues me regañó mucho por la escuela / de que la iba a dejar / y ya este / me dijo / <cita> ¿y dónde quedó tu sueño de ser médico? /  ¿dónde? </cita>
#
# 55 E:  pues  hubieras terminado el <siglas = [se.se.hache]> C C H </siglas>/  ¿no?
# 55 I:  sí  / y / y ya después / a estas alturas / sí me arrepiento porque / pues / la verdad el bachillerato que aquí nos dan / es bueno pero creo que carece de muchas cosas a comparación de un <siglas = [se.se.hache]> C C H </siglas>  <ruido = "carraspeo"/>
#
# 56 E:  ¡claro! y  más porque / no tiene como la / salida a // ciencias
# 56 I: y  más  lo que yo quería
#
# 57 E:  no / pues no
# 57 I: y / ya total que me salí / y entro / a la escuela / y mi mamá me dice / <cita> va / yo te apoyo / tú sabes que siempre has sido // lo que tú quieras / nada más no me defraudes / pero eso sí / ahí está el bachillerato y ahí te quedas </cita> / y pues ahí me metió / pues aquí estoy / y mi mamá sí me dio mucho apoyo pero / ya después / para esto / ella tiene otra pareja
#
# 58 E: mm
# 58 I: <tiempo = "14:50"/> y también él es muy machista / yo me llevo súper bien con él / o sea / en relación de / que yo / <transcripción_dudosa> me </transcripción_dudosa> llevo con él y / hasta <x>15</x>eso mis hermanos / es muy buena porque / somos amigos / nunca nos ha tratado mal ni / cosas de esas // pero él sí me / sí habló conmigo muy seriamente porque me dijo / <cita> ¿y qué vas a ser de bailarín? / ¿de bailarín vas a vivir? / ¿qué es lo que te ofrece / una vida de bailarín? </cita> / y ya / yo le empecé a decir que / pues que era a mí lo que me gustaba y además eso / es una carrera como cualquier otra / con / ventajas desventajas / y /  puedes hacer muchas cosas
#
# 59 E:  como cualquier otra  / mh
# 59 I: <ruido = "carraspeo"/> y ya como que él vio que yo tenía mucho interés en esto y que es / y que ya había pensado en todo eso que él me preguntó / y pues / él es el que me paga mi carrera / porque mi mamá pues / me ayuda mucho y ella / este / ahorita ya no trabaja / cuando yo entré a traba <palabra_cortada/> / a trabajar / a estudiar aquí / ella estaba en la Asamblea de Legisladores
#
# 60 E:  mm
# 60 I:  era dip <palabra_cortada/>  / era se <palabra_cortada/> este / secretaria de un diputado / entonces le iba muy bien en /  cuestión económica
#
# 61 E:  sí / sí  debe ser
# 61 I: y ento <palabra_cortada/> / y entonces cambia la legislatura y la sacan // no alcanzó a / su base para que se quedara ya de planta / entonces ahorita ella no tiene trabajo / y e <palabra_cortada/> / estamos ahora sí que / a expensas del / del señor este / se llama F/ <ruido = "carraspeo"/> / pero / pues / la verdad yo / doy gracias que mi mamá se haya encontrado alguien así / porque no cualquiera
#
# 62 E: no / pues no
# 62 I: no / y aparte / pues e <palabra_cortada/> / el señor es influyente / sí tiene varias cosas / tiene acciones en gaseras / apoya propagandas políticas / tiene este / rutas de camiones / o sea tiene un buen de cosas / entonces sí / pues sí es /  sí tiene varo
#
# 63 E:  ¿tu mamá es joven?
# 63 I: ¿eh?
#
# 64 E: bueno / ¿tu mamá es joven? /  bueno en re <palabra_cortada/>
# 64 I:  mi mamá  tiene treinta y seis años
#
# 65 E: ahh
# 65 I: sí / mi mamá es joven
#
# 66 E: ¡muy joven! <risas = "E"/>
# 66 I: <ininteligible/> joven
#
# 67 E: ¡muy muy joven!
# 67 I: sí
#
# 68 E:  cu <palabra_cortada/>
# 68 I:  y este  / y pues / ya después que mi mamá quería ser diputada <risas = "I"/> / y ahí andábamos en las encuestas y cosas de esas / porque sí metió sus / papeles para su diputación / pero no sé por qué motivo ya no se dio / y ya total que ella ahorita ya / le ayuda a él en cuestiones de secretaria porque pues ella es / lo que hace / pero pues no es un trabajo fijo para ella / y no es un sueldo fijo tampoco porque a veces se la lleva / a trabajar una semana y dos no / y e <palabra_cortada/> / y m <palabra_cortada/> / pero / el gasto nunca le ha faltado
#
# 69 E: sí /  pues no
# 69 I:  pero  / aquí la cuestión económica en / caso de nosotros / es de que este señor / pues sí le aporta y le aporta bien / pero le aporta para gastos de la casa / entonces para gastos de educación / a veces sí me veo un poco muy limitado porque ¡somos tres!
#
# 70 E: sí
# 70 I: <tiempo = "17:18"/> y entonces / mi hermano ya no estudia / se salió de estudiar hace mucho tiempo / de hecho perdió tres escuelas creo / mi hermana sí estudia / somos los dos únicos / pero pues yo estoy aquí enclaustrado todo el día y yo no le puedo ayudar económicamente / un poco más / o mínimo para mis gastos que ya no se preocupe por mí / entonces / y aquí la escuela pues sí es bastante / dinero lo que hemos gastado
#
# 71 E: sí / pues en vestuario y eso /  ¿no?
# 71 I:  <ruido = "carraspeo"/>  ajá // pero mi mamá sí me ha apoyado demasiado en la cuestión de que yo quise ser bailarín / y le / y a ella le gusta mucho verme bailar / entonces
#
# 72 E: ¡qué padre!
# 72 I: ha sido recíproco / la cosa con ella
#
# 73 E: oye / pero bueno / ella acepta que seas bailarín
# 73 I: ajá
#
# 74 E: y / dices que tu/ papá y / el novio de tu mamá
# 74 I: no / pues
#
# 75 E: son muy  machistas
# 75 I:  fíjate  / sí / pero / ya en ese sentido no me interesa lo que ellos piensen
#
# 76 E: bueno / pero ¿ya han hablado sobre /  eso?
# 76 I:  sí  / y / y aparte  pues
#
# 77 E:  ¿tu mamá  ya sabe?
# 77 I: ¿que soy  <extranjero> gay </extranjero>?
#
# 78 E:  ay / ajá
# 78 I: sí / pues yo // ¡huy no! / es que / no ese fue también otra historia bien / cañona  porque
#
# 79 E:  es que es  / súper fuerte / ¿no?
# 79 I: sí porque / imagínate ya / entré / entré a bailar / en los primeros / años que yo entré a bailar / pues ahí conocí a C // y pues ya ahí / le / el enamoramiento y
#
# 80 E:  <risas = "E"/>
# 80 I:  las flores
#
# 81 E: oye / pero primero / a ver / ¿cómo te das cuenta? / ¿siempre lo supiste?
# 81 I: sí / toda la vida / yo creo que desde // q <palabra_cortada/> me acuerdo <risas = "I"/> / hacía algo muy chistoso yo en la primaria / que yo / pues / obviamente tenía mis amigos hombres / ¿no?
#
# 82 E: mh
# 82 I: pero uno de ellos me gustaba mucho / se llamaba O / se llama O
#
# 83 E: chiquito /  o sea / estaban chiquitos <risas = "E"/>
# 83 I:  sí / chiquito bien  y me acuerdo que era como en cuarto de primaria
#
# 84 E: ajá
# 84 I: una cosa de esas / y él / empezó a andar con una niña / y de repente me botó porque yo era uña y mugre con él / entonces yo me puse así como que muy celoso y dije / <cita> no / este no se me va </cita> <risas = "I"/> // ¿y qué crees que hice?  <risas = "I"/>
#
# 85 E:  <risas = "E"/>  ¿te embarazaste?  <risas = "E"/>
# 85 I:  <risas = "I"/> no  <risas = "I"/> / no / que le bajo a su novia
#
# 86 E: ¡ihh!
# 86 I: y después boté a la novia / y ya me quedé yo con él de amigos
#
# 87 E: ajá
# 87 I: y ya seguíamos juntos / yo / entonces yo por eso digo que siempre pues he sido homosexual // y aparte bueno / esa es otra historia <ruido = "carraspeo"/> / este // pues ya ahí conocí a C / y ya de ahí / como estaba toda mi familia ahí metida pues se dieron cuenta / y empezaron los chismes / las malas interpretaciones / yo no andaba con él / de hecho / ni lo pelaba / o s <palabra_cortada/> o sea yo / yo a C lo conocí en / en el dos mil uno / en diciembre / y ya para abril del dos mil dos / el trece de abril de hecho es nuestro aniversario <risas = "I"/>
#
# 88 E: <tiempo = "19:46"/>  ay / qué bien
# 88 I:  empecé a andar con él
#
# 89 E:  ajá
# 89 I:  hasta esa  fecha / pero yo / pues yo / sí me gustaba / pero pues obviamente yo no sabía si él era <extranjero> gay </extranjero> o no / entonces / pasó otra cosa con él / é <palabra_cortada/> él estuvo / enamorado / pero súper enamorado / en aquel entonces / de otro chavo del mismo ballet / pero una vez al pendejo de C se le ocurre gritárselo ebrio // entonces / ya ahí / imaginarás el acabóse contra C porque pues / <cita> cómo es posible / que esto / y que lo otro </cita> / y ya después / <cita> cómo es posible que tú / si ya sabías que C estuvo enamorado de él / te vayas con él y / estés con él </cita> / o sea / fue un problema muy grande ahí / de hecho / mi hermano / según una vez lo golpeó y / cosas de esas / y mi hermano pues / otro machista peor que mi papá / pues a mí sí me / cuando yo le dije a mi mamá / tuve un problema muy fuerte con mi hermano / se llama L / de hecho nunca he llevado un <palabra_cortada/> una relación buena con él porque
#
# 90 E: ¿él es mayor o menor que tú?
# 90 I: mayor / un año
#
# 91 E: ah
# 91 I: nunca he llevado una relación buena con él / toda la vida hemos peleado / toda toda la vida / creo que / hasta la fecha <risas = "I"/> / pero / y ya de ahí que yo le dijera que era <extranjero> gay </extranjero> / pues / me empezó a decir que tenía una semana para cambiar mi forma de pensar / que le iba a pegar a C / que / que él lo iba a matar matar / y que si yo no me volvía / heterosexual que / él me volvía y que / así / puras cosas estúpidas y tontas de un / niño de / en aquel entonces yo tenía dieciséis
#
# 92 E: y él  dieci <palabra_cortada/>
# 92 I:  no  / él tenía dieciséis años / yo tenía quince // estamos hablando ya / cinco años <ruido = "carraspeo"/> // y pues ya / esa vez / que yo senté a mi mamá para decirle que yo era <extranjero> gay </extranjero> // pues m <palabra_cortada/> / mi her <palabra_cortada/> / hermano estaba ahí de metiche y mi mamá le dije que yo no quería que él estuviera ahí / que se fuera / ¿no? / pues que no le interesaba // y mi mamá dijo / <cita> no / es tu hermano y te tie <palabra_cortada/> / y // pues / déjalo que escuche </cita> / le digo / <cita> bueno / pero que se calle </cita> / y ya / le dije / <cita> ¿qué crees mamá?  <risas = "I"/>
#
# 93 E:  <risas = "E"/>
# 93 I: soy reina </cita>  <risas = "I"/>
#
# 94 E:  <risas = "E"/>
# 94 I: y ya / pues ya le dije que era <extranjero> gay </extranjero> / y mi mamá pues / fíjate / nunca me hubiera esperado una / reacción así de mi mamá / me dijo / <cita> mira / no sé qué contestarte // dame tiempo / y después hablo contigo </cita> / pero pues mi hermano / pegó el grito en el cielo / casi me pega ahí / mi mamá se metió y // y de ahí / <ruido = "palmada"/> ¿qué crees que pasó?
#
# 95 E: ¿qué?
# 95 I: uno de mis tíos estaba de chismoso en la puerta escuchó / y pues toda mi familia se enteró
#
# 96 E: <tiempo = "22:00"/> uh
# 96 I: sí / pues sí / y tuve muchos problemas / porque mis tías // y por lo de mi defecto / me han cuidado mucho toda la vida / mucho mucho mucho / y tengo una tía / que se llama V / que la quiero y la adoro / pero se quiso meter mucho en / en esta cuestión conmigo / hasta que yo le dije que no le importaba / que era mi vida / y que si la cagaba o no / pues yo tenía que / aprender a vivir por mis / por mí mismo / que me dejaran en paz // y pues hubo un tiempo en que toda mi familia me dejó de hablar
#
# 97 E:  <ruido = "siseo"/>
# 97 I:  toda toda  mi familia / y para esto vivo ahí / o sea yo / tu casa es mi casa
#
# 98 E:  gracias
# 98 I:  está ahí  en / donde está la / Escuela de A / por ahí / yo vivo
#
# 99 E: ajá
# 99 I: entonces / yo vivo // en <ruido = "palmada"/> la casa de mis abuelos / entonces ahí en esa casa / viven todos mis tíos por parte de mi mamá / toda la familia está ahí / entonces toda la familia la veo diario / convivo con ellos / yo tengo mi casa aparte / o sea es como un  departamento
#
# 100 E:  sí sí
# 100 I: pero pues / están ahí // y pues luego mis primos en / mis primos hombres también en el ballet / pues fueron problemas muy grandes / porque le querían pegar a C cada que se lo encontraban> y cosas así / entonces ya no / ya no me gustó / entonces ya decidí dejarles de hablar / me valió / y yo por C metía las manos al fuego
#
# 101 E:  ay
# 101 I:  y ya ahorita ay
#
# 102 E:  estás enamorado de C
# 102 I:  pues sí  / quince años que tenía / ahorita ya me doy cuenta de muchas cosas / ¿no? / pero ese es otro punto <risas = "I"/> // y pues sí <silencio/>
#
# 103 E:  así fue
# 103 I:  así fue  <risas = "I"/>
#
# 104 E: pero sigues andando con C / ¿no?
# 104 I: sí / hemos tenido muchos problemas // de hecho / ahorita hace poco acabamos de regresar / porque hemos cortado como tres veces
#
# 105 E: ajá
# 105 I: pero pues / las veces que hemos regresado ha sido bueno / y creo que el cariño que hay es / es lindo y no / y no creo que / que en el gremio de / de la homosexualidad se encuentren parejas así // es muy feo el mundo de // el mundo <extranjero> gay </extranjero> porque hay mucha porquería / así como tiene lo bueno / tiene lo malo y / y lo recontramalo / pues / no es / presunción ni nada pero pues // toda la vida he tenido así como que muchos pretendientes / pero que simplemente lo que buscan es sexo y no me / no me interesan / la verdad no / entonces <observación_complementaria= "tons"/> yo creo que / eh C y yo somos una pareja muy fuerte en ese sentido
#
# 106 E:  mh
# 106 I:  porque  no sólo somos eso / somos amigos / somos compañeros / somos casi hermanos // y n <palabra_cortada/> / comemos / cenamos / dormimos / bañamos / casi juntos / y no vivo con él / ya nos hace falta poco
#
# 107 E:  <risas = "E"/>
# 107 I:  pero  / me llevo súper bien con él / lo quiero mucho // pero hay muchos puntos que ahorita / ya que creces / ya tengo veinte años / a los / los quince / a los veinte es mucha diferencia / entonces sí pienso mucho las cosas con él / mucho mucho / tan sólo el hecho de vivir juntos ya / ya se / para mí sería como / como que casarme con él <risas = "I"/>
#
# 108 E: pues sí
# 108 I: <tiempo = "24:41"/> ya sería muy distinto / entonces / y de ahí para que mi mamá acepte que me vaya de su lado / porque mamá no quiere que me vaya /  y menos
#
# 109 E:  ay  / ¿pero y entonces?
# 109 I: no / o sea / no quiere en el sentido de que / pues que me quiere mucho y <cita> por qué me voy a ir </cita> / y ya / yo ya he platicado con ella y como que ahorita ya lo entiende y ya lo acepta / y el día que yo le dije que me quería ir / me dijo / <cita> pues te vas / pero dón <palabra_cortada/> yo sé dónde estás / cómo estás / y si no estás bien / te regresas / no te voy a dejar allá a l <palabra_cortada/> / a la deriva </cita>
#
# 110 E:  ay
# 110 I:  o sea mi  mamá sí me apoya mucho // y pues a C lo conocen / toda mi familia mi herma <palabra_cortada/> mi hermana / lo quiere mucho / mi mamá también // o sea hasta eso  él se lleva bien
#
# 111 E:  o sea / o sea  / es tu novio pues
# 111 I: es mi novio
#
# 112 E: ¿y bien? /  así
# 112 I:  ajá
#
# 113 E: y todo mundo lo sabe  y / ay / qué padre
# 113 I:  sí / mi padrastro no lo  sabe / y mi papá no lo sabe <risas = "I"/>
#
# 114 E: ay
# 114 I: y / pero pues es lo / de menos / no me interesan <ruido = "carraspeo"/>
#
# 115 E: pues sí
# 115 I: sí sí sí / ha sido
#
# 116 E: pero / pero vive / o sea / ¿tu padrastro <ruido = "palmada"/> vive con ustedes? /  o
# 116 I:  sí  / ahorita ya // tiene como / medio año que empezó a vivir con nosotros / porque antes // pues no teníamos un espacio muy grande / entonces construimos una especie de departamento / y es donde estoy viviendo ahorita y / pues ya mi papá / mi papá / mi padrastro y mi mamá pues ya viven en su cuarto y yo en el mío / cada quien tiene su espacio / pero pues // creo que nos vamos a salir ya <risas = "I"/> / en uno de estos días /  porque
#
# 117 E:  sí
# 117 I: ya lo que quiere mi mamá es un terreno para ella
#
# 118 E:  pues sí
# 118 I:  su casa  / obviamente un sueño de / una familia / ¿no? // su casa / su terreno / sus hijos / y sus nietos / nada más
#
# 119 E:  híjole <ruido = "palmada"/>
# 119 I:  no que los  tíos / los primos / los <ininteligible/> / ay> no
#
# 120 E: toda la familia  ahí / ¿no?
# 120 I:  es tan f <palabra_cortada/>  / sí es / es bonito y es feo a la vez / porque // cuando / es cuestión / de unión familiar pues ahí están todos / pero cuando es de chismes / ay / cómo / cómo harta la familia la verdad / en ese sentido // y yo siempre / y yo siempre le he dicho a mi mamá que // que mi familia son / tres personas / ella / mi hermana / y mi hermano / nada más / que mis abuelos y ellos / sí son mi familia pero / ¡no! / no tienen / no tienen injerencia en mí / ya / hasta ahí / con ellos / sí son / pero no son
#
# 121 E: sí sí  sí
# 121 I:  sí  / y ya // entonces // también por eso / y luego soy como / en mi casa soy muy serio / por todo este tipo de cosas / entonces casi no le hablo a nadie / estoy // casi no estoy en mi casa / o sea // pues aquí estoy todo el día / y luego de aquí me voy a trabajarr / y pues ya
#
# 122 E: ¿en qué estás trabajando?
# 122 I: entré a un restaurante aquí en Z R a bailar //  folclor
#
# 123 E:  ah  / órale
# 123 I: pero ahorita no estoy de / no estoy / de lleno / acabo de entrar // entonces  este
#
# 124 E:  por eso  faltas los / j <palabra_cortada/> / ¿qué? /  ¿miércoles?
# 124 I: <tiempo = "27:07"/>  la  / los días que falto a tu clase <risas = "I"/> / es por eso // y pues ya
#
# 125 E: órale / y qué / ¿sí te pagan bien?
# 125 I: pues más o menos / no es la gran cosa pero pues / mínimo para mis gastos sale
#
# 126 E:  ah
# 126 I:  y no es  / no es mucho tiempo // pero lo tuyo es otra cosa / lo tuyo es de una academia // en donde t <palabra_cortada/> / tienen una t <palabra_cortada/> temporada de / funciones
#
# 127 E:  mm
# 127 I:  y entonces  / es una academia de niñas / entonces piden bailarines ya / más o menos experimentados / para que el espectáculo como que crezca un poco
#
# 128 E: ajá
# 128 I: y ya / ahí es donde estoy ahorita // pero / lo <palabra_cortada/> esos ensayos son de / de cinco a ocho / y las / funciones del / restaurante son de ocho a once
#
# 129 E: órale / ¿y luego cómo te regresas?
# 129 I: pues en metro / de ahí de / Z R // todo
#
# 130 E:  ¿y sí alcanzas?
# 130 I:  toda la línea  verde / ajá / hasta / U
#
# 131 E:  órale
# 131 I:  sí / sí alcanzo
#
# 132 E: oye / pero aparte tu / colonia sí es como muy peligrosa / ¿no?
# 132 I: no
#
# 133 E:  ¿no?
# 133 I:  pues  / ya está más tranquilo / antes sí // ya ahorita ya no
#
# 134 E:  sí
# 134 I:  ya  ahorita / pues ya empezaron mucho a vender droga pero
#
# 135 E: <risas = "E"/> /  ¿y a poco antes no?
# 135 I:  y más ahí en mi calle  <risas = "I"/>
#
# 136 E: ¿y a poco antes no?
# 136 I: no / antes no / antes no vendían nada de eso / ahorita ya / empezaron con eso
#
# 137 E: ah / órale
# 137 I: de hecho mi / creo que mi calle es la más conocida / porque ahí es do <palabra_cortada/> / el núcleo de donde venden la droga
#
# 138 E: ah / ¿sí?
# 138 I: enfrente de mi casa está // todo lo / la gente que vende ese tipo de cosas
#
# 139 E: <risas = "E"/>
# 139 I: y luego en la esquina hay un expendio de cervezas / o sea / hay un  buen
#
# 140 E:  o sea  / ¿es la siguiente cuadra? / ¿de la E?
# 140 I: no / d <palabra_cortada/> <ruido = "carraspeo"/> // de donde está la iglesia
#
# 141 E: la iglesia / la igles <palabra_cortada/> / sí
# 141 I: de G
#
# 142 E: ajá
# 142 I: de ahí dos cuadras / para abajo
#
# 143 E: ah /  órale
# 143 I:  ahí  // entonces / pero pues / está tranquila y / bueno / más que nada como es / es calle cerrada donde yo vivo / pues no // no hay tanto problema
#
# 144 E: oye / y qué ahí / este / ¿no hay agresión? // ¿porque // porque seas <extranjero> gay </extranjero>? / digo no / no  porque n <palabra_cortada/>
# 144 I:  ah
#
# 145 E: digo / no se los tienes que decir a  todo el mundo
# 145 I:  pero por  // sí / sí sí sí te entiendo // no / nunca me han agredido en mi / en mi cuadra / ni en mi calle / no
#
# 146 E: ah /  qué bueno
# 146 I:  y yo  creo que también ha sido porque mi papá / y la familia de mi papá viven / en la misma cuadra
#
# 147 E: sí / pues es como que la misma /  gente
# 147 I:  es la misma  gente que me ve y / y como que / y como no ando de loca ahí joteando por todos / todos lados // no / hasta eso no / y más que soy muy serio por donde yo vivo / no me gusta
#
# 148 E:  sí
# 148 I:  ni  siquiera convivir en la / con la gente / pues no /  hasta eso no
#
# 149 E:  oye y  // ay perdón
# 149 I: <ruido = "carraspeo"/>
#
# 150 E: es que ahora que decías lo de <cita> como loca </cita>
# 150 I: ajá
#
# 151 E: ¿tú cómo? // es que // hay una diferencia muy grande entre tener una preferencia sexual / y / y querer ser // como las personas del otro sexo // ¿no?
# 151 I: ajá
#
# 152 E: <tiempo = "29:55"/> o sea / una cosa es querer ser como mujer
# 152 I: ah /  sí sí sí
#
# 153 E:  y <x>30</x>otra cosa  es que
# 153 I: tener preferencia <extranjero> gay </extranjero>
#
# 154 E: ajá // ¿tú / cómo / piensas / eso?
# 154 I: pues mira / yo siento que el hombre es hombre y nunca va a // poder ser mujer por más que se opere / o se ponga / o se haga / o se quite // entonces en ese sentido / no / a mí me gusta // y no te digo que me gusta ser homosexual / no me gusta / yo no pedí ser homosexual / pero no / no voy en contra de lo que soy // o sea sería tonto decir que me gusta un lápiz cuando me gusta una pluma // entonces / o sea / yo no pedí ser homosexual / no me gusta
#
# 155 E:  ¿por qué no te gusta?
# 155 I:  pero me acepto como soy  // porque / ser homosexual es estar siempre solo //  entonces <observación_complementaria= "tons"/> ahí
#
# 156 E:  pero tú  no has estado solo
# 156 I: no / o sea // pero la gente te rechaza mucho // o sea aunque sea muy poca / pero sí hay / hay una discriminación a los demás <silencio/> y por eso me gusta la danza / porque ahí no te discriminan
#
# 157 E: ah
# 157 I: y <palabra_cortada/> / yo me imagino que si fuera un trabajo de
#
# 158 E: de cualquier otra cosa
# 158 I: pues ahí sí se vería mucho el <cita> ay / es maricón </cita> / y cosas así / pero pues en la danza no / en la danza es más abierta a ese sentido
#
# 159 E: mh
# 159 I: de cuestiones // por eso no me gusta ser homosexual / pero aquí en la danza // no es de que no me guste / pero pues es soy más aceptable <silencio/>
#
# 160 E: sí / pero bueno / pues si no hubiera / discriminación / no tendrías
# 160 I: no //  no
#
# 161 E:  o sea eso es  lo único que no te gusta pues
# 161 I: no / fíjate que // que no me gusta porque / me hubiera gustado tener una familia // tener hijos / casarme / ser un hombre normal // a mí sí me hubiera gustado eso / pero no me voy a engañar casándome / ni teniendo hijos / y teniendo un / un amante hombre por otro lado / creo que sería tonto
#
# 162 E: sí / no /  y sería
# 162 I:  entonces
#
# 163 E: deshonesto / ¿no?
# 163 I: sí
#
# 164 E: de tu parte
# 164 I: para mi familia primero que nada si es que llegara a tener / y para mí mismo // estar engañando a dos personas //  entonces <observación_complementaria= "tons"/> ahí sí no
#
# 165 E:  órale  // pero por qué / o sea / ¿pero eso de la familia por qué es? / ¿porque no quieres estar solo? / ¿o porque de verdad te gustaría / vivir la experiencia de ser padre?
# 165 I: <tiempo = "32:05"/> no / la verdad es que / yo creo que es // ahí vería qué tan capaz soy para resolver // problemas / en cuestión de lo que yo quiera // en cuestión de mis hijos / de mi familia / de mi hogar // entonces <observación_complementaria= "tons"/> sí me gustaría tener a mí un hogar / pero con // pero p <palabra_cortada/> / o sea / puedo tener mi hogar / pero no tener descendencia / y a mí sí me gustaría tener una descendencia
#
# 166 E:  mm
# 166 I:  entonces <observación_complementaria= "tons"/>  eso sí //  pero pues // ya
#
# 167 E:  pues bueno / ya / actualmente  la sociedad es tan abierta que
# 167 I: sí / al rato adopto a alguien y ya <risas = "I"/>
#
# 168 E: ajá y ya // hasta / bueno no sé me / un día vi una película así / que eran / eran / dos chavos y // adoptaron a un niño / pero / lo padre es que // le enseñaron como / o sea el niño vivió en un ambiente diferente
# 168 I:  pues obviamente
#
# 169 E:  desde pequeño  // pero no por eso fue <extranjero> gay </extranjero>
# 169 I: ¿ah no?
#
# 170 E: no
# 170 I: ah / fíjate que / eso es lo que
#
# 171 E: no / no fue / o sea no fue <extranjero> gay </extranjero> / por eso / y y fue padre porque l <palabra_cortada/> / los papás <risas = "E"/> // no / no tuvieron problema con eso / y más bien el niño como que / de verdad / no tenía prejuicio / ¿no?
# 171 I: sí sí sí
#
# 172 E: aunque él no era / ¿no?
# 172 I: ajá / eso sí es bonito y y <palabra_cortada/> / yo // pero no sé / siento que // que me gustaría más ayudar a un niño de la calle / que adoptar a alguien
#
# 173 E: pues sí
# 173 I: no sé <silencio/> no sé / que en cuestión ya de dar / todo / a un niño // tendría que ser mi ni <palabra_cortada/> / mi sobrino o algo de mí porque si es algo / más e <palabra_cortada/> externo / o tendría que ser una situación en / que yo diga / <cita> okey vamos a </cita> / que no sepa que es // que no es / que no es mi hijo / o que no es mi sobrino / que sepa que // no sé / una mentira si tú quieres piadosa / pero // pero sí me gustaría mucho educar y mantener a una vida / a un ser humano
#
# 174 E: ¡ay / qué padre!  <risas = "E"/>
# 174 I:  ajá
#
# 175 E: ¡qué padre!
# 175 I: eso sí me encantaría
#
# 176 E: <ruido = "clic"/> no / pues sí / ¡huy! // fíjate / si algunos / heterosexuales pensaran como tú
# 176 I: <risas = "I"/>
#
# 177 E: otra cosa sería
# 177 I: pues sí
#
# 178 E: ay / qué cosas / de veras que <silencio/> es como <silencio/> es como / parece / ya no debería de ser como un tabú / ni debería de ser / difícil / ¿no? / pero bueno / a mí misma me costó
# 178 I: <tiempo = "34:35"/> trabajo
#
# 179 E: trabajo / ¿no? / cómo / decirlo // ¿no?
# 179 I: mh
#
# 180 E: igual / no sé / lo que pasa es que // en esta escuela se da una situación muy chistosa / ¿no? / todo mundo entra / supuestamente siendo heterosexual / y en el último año // pues // así uno por uno / ¿no? <risas = "E"/>
# 180 I:  <risas = "I"/> van cayendo <risas = "I"/>
#
# 181 E:  en el transcurso / así pero así  / y / bueno / sobre todo los chavos / ¿no? / así van // que también las chavas // que también las chavas /  la verdad
# 181 I:  sí
#
# 182 E: pero / pero sí / sobre todo los chavos / vas viendo / ¿no? / así como el ca <palabra_cortada/>
# 182 I:  <risas = "I"/>
#
# 183 E:  así como  // tenía diez / y así / uno / dos / así <risas = "E"/>
# 183 I: yo tenía diez hombrecitos
#
# 184 E: ajá // ¿y en tus compañeros cómo has visto eso?
# 184 I: mm / ¿mi homosexualidad?
#
# 185 E: ¡no!
# 185 I: ¿o de qué?
#
# 186 E: la de tus compañeros / no / es que yo creo que / no porque / tengan en algún momento / prácticas homosexuales
# 186 I: sean  homosexuales
#
# 187 E:  la gente es  homosexual
# 187 I: ajá
#
# 188 E: o sea / siento que el ambiente de la escuela / se / se presta // por decirlo de alguna manera
# 188 I: para ese tipo de cosas
#
# 189 E: para e <palabra_cortada/> / sí / y  precisamente
# 189 I:  o de experiencias  / ¿no?
#
# 190 E: exactamente // pero / yo creo que no necesariamente por eso / ya este
# 190 I: ya son <extranjero> gays </extranjero>
#
# 191 E: ajá
# 191 I: sí sí sí // ¿esa es la pregunta? // ¿cómo los veo a ellos? /  ¿o qué?
#
# 192 E:  sí  / sí / cómo has visto eso / ¿en tu generación ha pasado?
# 192 I: sí / pues en el juego de la botella / o cosas de esas / que estamos en el relajo y se / y este m <palabra_cortada/> / por eso me gusta mucho es <palabra_cortada/> / este ambiente de la escuela / porque somos tan abiertos a todo tipo de cosas y de experiencias // que el / yo creo que la gente del folclor / es la que menos tabús tiene // que sí hay muchas excepciones / ¿no? / mucha ñoñería aquí también / pero / tan sólo / mis amigos en general / sí son // somos muy abiertos a todo / y a / platicamos de temas tan // controversiales para la sociedad que / no nos da pena / ni / nos da / cosa / hacer un juego / como el de la botella / que tienes que besar a / en mi caso a una mujer / o ellos a un hombre / que lo hacemos / y nos divertimos / y nos cagamos de la risa / pero pues ellos // en su pedo / o sea / cada quien tiene sus preferencias / y eso no influye en su forma de ser // yo creo que ahí sí // con mis amigos <ruido = "palmada"/> no <silencio/>
#
# 193 E: este
# 193 I: <tiempo = "36:59"/> ay / ahí estaba
#
# 194 E: <risas = "E"/> ajá
# 194 I: y pues ya // no no he visto así // que se vuelvan por eso / cosas así
#
# 195 E: no / no por eso / sino porque / de repente entra en la diná <palabra_cortada/> a la dinámica / no  sé
# 195 I:  mh
#
# 196 E: de repente como la convivencia con / porque ya sabes / ¿no? / que cada maestro tiene su
# 196 I: su  preferido
#
# 197 E:  su protegido  / y
# 197 I: ajá / no / no / hasta eso no / creo que // somos demasiados cap <palabra_cortada/> / demasiado capaces para identificar / si es o no es / y al m <palabra_cortada/> / y fíjate que pasa algo muy bien chistoso entre los homosexuales // como que nos olemos <risas = "I"/>
#
# 198 E: es lo que dicen
# 198 I: sí pues / por ejemplo / de mis amigos yo no di <palabra_cortada/> / yo te diría que nadie // pero pues hay gente que dice que no / y yo te digo que sí // por ejemplo de tu otro grupo / yo digo que J // el C // ahí sí / yo le / y <palabra_cortada/> yo pondría las manos al fuego por que sí // y de que tienen tendencias bisexuales / por ejemplo // V / M <risas = "I"/>
#
# 199 E: ¿cuál V?
# 199 I: A
#
# 200 E: ¿V?
# 200 I: V el
#
# 201 E: ¿A?
# 201 I: no / el otro / el que va en mi salón
#
# 202 E: ah
# 202 I: él // ¿quién más? / y de primero / pues hay muchos / que dicen que no son / y ahí se les ve la jota atrás de ellas
#
# 203 E:  <risas = "E"/>
# 203 I:  pero no  <risas = "I"/> // pero pues es chistoso mientras // y y como que te da mucha curiosidad por / nada más el hecho de enterarte si es o no es // y ya / pero pues / es / a mí me da mucha risa
#
# 204 E: sí
# 204 I: <ininteligible/>
#
# 205 E: no / pues el / asunto este de que // bueno a mí / no / no es que me saque de onda pues no no / no tendría por qué tener // implicaciones pero // pues sí / el hecho de que M viva con H / digo no
# 205 I: pero ahí yo lo veo por una cuestión más de necesidad
#
# 206 E: sí sí / o sea / yo sé que es / eso pues
# 206 I: ajá
#
# 207 E: pero / pero finalmente vive
# 207 I: sí // pero //  bueno n <palabra_cortada/> // no
#
# 208 E:  sí / no estoy diciendo que suceda nada  // pero sí es un ambiente
# 208 I: distinto
#
# 209 E: distinto / ¿no? <silencio/> o sea / no son cuates pues / o sea / no creo que / que H asuma un // un asunto de cuates / o sea / no estoy diciendo que qui <palabra_cortada/> / a lo mejor // yo creo que es una dinámica distinta
# 209 I: <tiempo = "39:15"/> mm // pues yo // por lo que me he enterado sí ha habido algo ahí de // de querer echar mano / o cosas de esas / pero / pero // no creo que M se deje <risas = "I"/> o cosas de esas eh // si hay un interés / por parte de H / yo digo que sí // pero pues hasta ahí
#
# 210 E: es que ya / está grande / está solo / lo que tú  decías / ¿no?
# 210 I:  está solo
#
# 211 E: está solo / entonces <observación_complementaria= "tons"/> yo creo que /  ha de ser muy fuerte para él
# 211 I:  es fíjate que / terminar así  / mi vida / me daría mucha tristeza // tener terminar así / sin nada / sin nadie <silencio/> somos tan / vulneblab <palabra_cortada/> vulnerables a una soledad // que necesitamos un / un / algo // un / mínimo / un perro ahí que te esté / <cita> guau guau guau </cita>
#
# 212 E: ladrando / ¿no?
# 212 I:  sí>
#
# 213 E:  perro que te ladre  <risas = "E"/>
# 213 I: ajá
#
# 214 E: oye / ¿y por qué tú te ves tan agresivo?
# 214 I: ¿me veo agresivo?
#
# 215 E: o sea / por qué / ¿por qué eres tan agre <palabra_cortada/>? / o sea tan / sí tan agresivo> // si no eres agresivo
# 215 I: ¿cómo agresivo?
#
# 216 E: o sea e <palabra_cortada/> / eres como // así / cuando hablas de repente eres así como // puedes ha <palabra_cortada/> / puedes ser hasta / muy ofensivo o
# 216 I:  ah
#
# 217 E:  no conmigo  / no conmigo / pues / ¿no?
# 217 I: ya ya ya / en mi  forma
#
# 218 E:  pero  sí te he visto así y / <ruido = "imitación de gritos />
# 218 I: <risas = "I"/>
#
# 219 E: te la pasas ahí / protestando por // con /  por todo
# 219 I:  con todos  y contra todos / ¿no?
#
# 220 E: sí de veras que yo no sé qué co <palabra_cortada/> / conmigo no / no eres así / pero
# 220 I: no
#
# 221 E: sí
# 221 I: pero no me considero agresivo / me considero // una persona muy sincera / pero / demasiado sincera que si // que si me caes gordo te lo puedo decir en tu j <palabra_cortada/> / en tu jeta así / <cita> me caes hasta en la punta de la chingada y vete de aquí </cita>
#
# 222 E: ajá
# 222 I: y n <palabra_cortada/> / y soy muy elitista con mis amigos // mucho muy elitista / no me gusta tener cualquier tipo de gente a mi lado
#
# 223 E: mm
# ...
#
# 246 E: <tiempo = "46:40"/> ¿y qui <palabra_cortada/> quién fue la  maringuilla?
# 246 I:  V
#
# 247 E: ah / V
# 247 I: V V / el que va en tu grupo
#
# 248 E: ah
# 248 I: bueno / en tu otro  grupo
#
# 249 E:  ajá
# 249 I: él // él fue la maringuilla / pero me gustó porque yo quería bailar cúrpites porque pues la maringuilla nada más estás  ahí
#
# 250 E:  sí
# 250 I: bien modosita tú / pero pues ya / en cúrpites ya es zapateado y direcciones / y la máscara pues de plano no te deja ver ni mais
#
# 251 E: sí / sí
# 251 I: y luego las mangas / o sea / sí  me gustó
#
# 252 E:  ¡y pesan!  / ¿no?
# 252 I: sí / pesan
#
# 253 E: sí pesa un buen / y la máscara es de madera / ¿verdad?
# 253 I: sí
#
# 254 E: pero sí está gruesa /  ¿no?
# 254 I:  las  rendijitas para ver ahí // y l <palabra_cortada/> / y como eran muchas diagonales / y cruces / y frentes y // entonces <observación_complementaria= "tons"/> sí estabas ahí <cita> ah </cita>
#
# 255 E: <risas = "E"/>
# 255 I: fue muy / a mí me gustó ser cúrpite esa vez / y para las danzas me gustó mucho ser maringuilla // y fíjate que hasta / para cuestión // <ruido = "eructo"/> perdón / de vestuario // el mío / el del de / maringuilla / mi mandil que bordé / quedó s <palabra_cortada/> súper bien / me / a mí me encantó el mandil / de hecho A me lo quería comprar
#
# 256 E: el
# 256 I: el C
#
# 257 E: ajá
# 257 I: me lo quería comprar // y fue el que usé para / cúrpites / y hasta eso sí / y el de // el de danza de chinelos también lo bordé todo yo // entonces <observación_complementaria= "tons"/> ahí / sí me he hecho yo mis cosas también / y me gusta hacer mis cosas / y me gusta que las cosas queden bien
#
# 258 E: pues sí
# 258 I: y pues ya
#
# 259 E: que sea vistoso / y que / esté bien vestido todo
# 259 I: ajá // y es muy distinto en / cómo soy en la carrera y cómo soy en el bachillerato
#
# 260 E: ¿por qué? / ¿cómo eres en la carrera?
# 260 I: en la carrera pues / ahorita ya soy muy huevón / demasiado huevón / ya no me gusta / ya estoy harto / ya me quiero ir / de aquí
#
# 261 E: ihh / y te vas a estar otros  cuatro años
# 261 I:  cuatro años  / pero regreso a los veintiséis / <risas = "I"/> me voy / y ahorita / no / no me quedo // no me quedo ahorita a hacer / la licenciatura // ahorita como estoy en un proyecto de irme a España tres meses
#
# 262 E: ah  sí con
# 262 I:  a bailar  // mh /  entonces <observación_complementaria= "tons"/>
#
# 263 E:  también  está M / ¿no?
# 263 I: sí / entonces <observación_complementaria= "tons"/> pues ya / yo ahorita tengo eso en mente y ya me voy / ya regresando si / tengo ganas o / o tiempo porque también ya / ahorita ya saliendo / ya no puedo depender económicamente de mi mamá / o sea ya tengo que ser una persona / pues ahora sí que / que solvente sus gastos propios / ¿no? // entonces <observación_complementaria= "tons"/> sí / esos // ya es otra cosa de qué hablar porque ya tengo que pagarme yo el estudio y / pasajes / y trabajar / y alimentarme / ya soy yo / ya no l <palabra_cortada/> / ya saliendo de esta escuela yo creo que ya / mi her <palabra_cortada/> / me doy este / olvidado de mi madre / y ya solito a ver qué hago / porque ya no es posible que a mis veinte años todavía me estén manteniendo
#
# 264 E: <tiempo = "49:08"/> sí / pero bueno / también no / no / no por / ganar dinero vayas a /  dejar
# 264 I:  no
#
# 265 E: porque mira / aquí el asunto es que // se abre la licenciatura / y entonces ya / tu título de bailarín  ejecutante
# 265 I:  ya vale
#
# 266 E: ya
# 266 I: ya o sea
#
# 267 E: muchas gracias / o sea / quien tenga un papel de licenciatura
# 267 I: pues obvio
#
# 268 E:  entonces
# 268 I:  es lógico
#
# 269 E: o sea finalmente sí vas a / o sea sí tienes que pensar en eso
# 269 I: sí / y fíjate que // que / antes de que se abriera la licenciatura aquí / yo ya había planeado ir <palabra_cortada/> / este irme a Colima a estudiar la licenciatura allá
#
# 270 E: <ininteligible/> Zamarripa
# 270 I: ajá // pero voy a ver cuál me ofrece mejor / porque otra de las cosas por las que me quería ir era // librarme de esta ciudad / de esta gente ya / salirme de aquí / entonces conocer nueva gente / nuevos lugares // otro // como vivir en otro mundo / ¿no? / allá
#
# 271 E: <risas = "E"/>
# 271 I: totalmente distinto / entonces
#
# 272 E:  pues sí / estaría bien
# 272 I:  por eso me quería ir  // más bien para allá
#
# 273 E: está la opción / esa es una y la otra creo que es Veracruz / ¿no?
# 273 I: Veracruz / y hay varias pero pues creo que las mejorcitas es la de Colima y Veracruz
#
# 274 E: mh
# 274 I: y este // pero no sé todavía // ahorita / regresando de España pues yo creo que ya / me metería a estudiar la licenciatura de lleno / y ya decidiría en dónde / si aquí o allá
#
# 275 E:  pues sí
# 275 I:  porque  también es / tenía / tengo un // la ilusión o
#
# 276 E:  proyecto
# 276 I:  o el que  // ajá / de meterme ahí a A H
#
# 277 E: ah / tú sí quieres  entrar al
# 277 I:  ajá
#
# 278 E: folclórico
# 278 I: pero // nada más por quitarme la espinita de que / yo que / yo sé estar ahí / tengo que estar ahí / y otra porque a mí mamá le encanta ese ballet / entonces <observación_complementaria= "tons"/> / la primera es la mía / de que yo quiero estar ahí // un tiempo / no me gustaría enclaustrarme ahí bailando con ella // pero pues ya la otra es / mi mami / que me gustaría / ella me ha dicho que / le gustaría mucho verme bailar ahí
#
# 279 E: ¿y cuál es la estatura mínima?
# 279 I: creo que / uno setenta y seis / setenta y siete
#
# 280 E: ¿y cuánto mides?
# 280 I: setenta y cinco / entonces sí estoy chaparrito para eso // para eso sí estoy enano
#
# 281 E: sí / pues sí
# 281 I: pero por ejemplo hay un chavo de primero / que está un poquito más bajo que yo / pero y / está en la compañía y ya tiene creo que tres años que está ahí
#
# 282 E: ¿pero en la residente?
# 282 I: mh
#
# 283 E: ah / en la residente // lo bueno sería estar  en la primera
# 283 I:  en la primera  // de / de hecho ahorita que / acabamos de ir / pues / sí ves a los chavos // sí están muy altos la verdad / ¿te acuerdas de R? / ¿o sí conoces a R?
#
# 284 E: <tiempo = "51:34"/> sí
# 284 I: pues él se ve chaparrito al lado de ellos / y sí está grande / grandote el chavo  este
#
# 285 E:  sí  // híjole
# 285 I: sí / pues sí / ahí la cuestión no es de / talento / sino de estatura
#
# 286 E: ¡sí / ay / pues ya sabes!
# 286 I:  sí
#
# 287 E:  ya  sabes que así es / ¿no? / en realidad / sólo trabajan / el  porte y / proyección
# 287 I:  el porte / presencia  / proyección
#
# 288 E: pero pues / cero otra cosa
# 288 I:  no
#
# 289 E:  no  les pidas / nada más
# 289 I: sí <risas = "I"/> / exacto /  porque no
#
# 290 E:  o sea / nunca  bajes la mirada porque / <risas = "E"/> no vas a ver nada / ¿no?
# 290 I: exacto / es lo que pasa con ellos // pero pues sí tienen mucha altura y / se ven bien / hasta eso
#
# 291 E: sí / pues sí / es muy atractivo / para eso está diseñado ese espectáculo
# 291 I: que no es folclor / es netamente un espectáculo // o sea tiene mucho // de folclor y espectáculo
#
# 292 E: mh
# 292 I: ¿de qué estábamos hablando?
#
# 293 E: sí dell folclor
# 293 I:  ah / sí <ruido = "carraspeo"/>
#
# 294 E:  y que  eso no es folclor
# 294 I: y pues sí // o sea en cuestión de A pues es lo que te piden / mucha estética nada más porque / en cuestión de pasos ves a sus bailarines y nomás no // y las mujeres peor // de arriba pues tienen todo / pero tápales los pies ahí porque
#
# 295 E: ay / no
# 295 I: no
#
# 296 E: es horrible
# 296 I: si no a lo que también me gustaría entrar es a J / pero pues // también es muy bueno ese espectáculo
#
# 297 E: esa es una / buena propuesta / ¿eh?
# 297 I: sí /  es muy buena
#
# 298 E:  a mí me gusta
# 298 I: ajá
#
# 299 E: porque eso / es innovador / ¿no? / aunque no tiene como <ruido = "clic"/> // no tiene como más trama pues / en el sentido de que no está contextualizado
# 299 I: ajá
#
# 300 E: o sea / sí es una propuesta // o sea / ya ya no es / el ballet folclórico / ya no es ballet  folclórico
# 300 I:  ya no es
#
# 301 E: o sea sí / estamos tomando un aspecto / del baile tradicional / pero l <palabra_cortada/> / lo armamos en en una propuesta nueva / ¿no?
# 301 I: sí
#
# 302 E: que es J / a mí sí me gusta
# 302 I: pero fíjate que // que en cuestión de espectáculos / yo creo que // pues es / ¿has visto el espectáculo de Z?
#
# 303 E: mh
# 303 I: también es bueno / pero pues / ya e <palabra_cortada/> / es  cuestión de gustos
#
# 304 E:  pero es como lo  mismo / ¿no? / pero es como igual / el retrato  del
# 304 I:  exacto  / pero / yo siento que ese tipo de / de espectáculos / es / es / eso y es lo que presentan / en cuestión de producción / que es lo que no hay producción de / de un espectáculo así / tan sólo aquí la escuela / tiene muchos proyectos muy buenos / y hay muchas ideas / interesantes <ruido = "palmada"/> / y hay // pues / hay bailarines aquí en la escuela / pero pues lo que no hay es un buen presupuesto / que te digan / <cita> okey / ¿cuánto quieres? / ¿qué vamos a gastar? / ¿qué luces? / ¿qué vestuarios? / ¿qué? </cita>
#
# 305 E:  sí
# 305 I: <tiempo = "54:10"/>  o sea todo  / todo eso // todo lo que conlleva una producción // no sé / carteles / propagandas / información / o sea / la escuela es un acervo cultural tan grande pero no tenemos un sí
#
# 306 E: sí / imagínate / muchas de las prácticas escénicas este / de los / guiones para práctica / son  buenísimos
# 306 I:  son buenos  / muy  muy
#
# 307 E:  que eso  / llevado hasta sus últimas consecuencias /  en producción
# 307 I:  se vería  // pues sí
#
# 308 E: sería buenísimo / y han salido varios // varios varios varios
# 308 I: ¿a ti cuál te ha gustado más?
#
# 309 E: híjole <risas = "E"/> / es que a mí / ¿sabes qué? / yo sí soy muy / yo sí me pongo mucho la camiseta de la escuela / a pesar de
# 309 I: ajá
#
# 310 E: todo y de // que / hay problemas y esto / a mí sí me gusta mucho cada cosa que hace la escuela / sea el cuadro que ha // persistido o
# 310 I:  de / por veinte años
#
# 311 E:  o se ha mantenido  // por / veinte años / o sea a mí me sigue gustando / es impresionante / o sea yo vengo y / veo no sé / Chihuahua o / Baja California / de la misma manera que yo lo bailé / y a mí me sigue  gustando
# 311 I:  sí  /  y
#
# 312 E:  o sea  yo sí
# 312 I: y / tenemos maestros muy buenos para prácticas / H es / buenísimo el canijo este / me gusta mucho la forma de trabajar prácticas de él / y de / de este B / B también es muy bueno
#
# 313 E: es que se atreve / ¿no? / a muchas cosas
# 313 I:  ajá
#
# 314 E:  aunque  yo soy más del lado / tradicional y costumbrista /  o sea a mí sí
# 314 I:  de M
#
# 315 E:  sí
# 315 I:  y de F  / y
#
# 316 E: sí a mí / sí / sí es como la / me gus porque igual nosotros tuvimos desde el montaje más costumbrista tradicional hasta el más así
# 316 I: soflamero / ¿no?
#
# 317 E: ajá /
# 317 I:  <ruido = "carraspeo"/>
#
# 318 E:  pero  / pero sí siempre como que disfruté más una / una buena clase de técnica con M // que
# 318 I: el estilito de B
#
# 319 E: ajá / sí  siempre
# 319 I:  sí sí  sí
#
# 320 E: siempre agradecí como más / esa / esa parte / ¿no? / de M / de
# 320 I: <ruido = "tos"/> sí / a mí en cuestión escénica / me gusta mucho el trabajo de mi <palabra_cortada/> / de H y de / A B
#
# 321 E:  mm
# 321 I:  de  F B
#
# 322 E: ajá
# 322 I: de ellos me gusta mucho su trabajo / y de P / y de // de N / de N
#
# 323 E: ay
# 323 I: d <palabra_cortada/> de / ay / M y E también son muy buenos
#
# 324 E: en clase / ¿no? // en clase
# 324 I: <tiempo = "56:24"/> sí pero ya en el la / en la cuestión ya de / de /  escena
#
# 325 E:  propuesta   escénica
# 325 I:  me gusta  más <ruido = "palmada"/>
#
# 326 E: H
# 326 I: H y B
#
# 327 E: sí / pues porque sí tienen como más esta visión / de show o espectáculo / o sea danza  como show
# 327 I:  pero fíjate  que este / H no tanto / H se va mucho por // la / dice él <cita> disciplina de escena </cita> / que sean líneas / que sean cuadros / que sean cruces / que sean / que el paso / que todos parejos / que esto / y que lo otro / entonces es lo que me gusta de él que es / se fija mucho en esos detalles y es lo que hace que un cuadro resalte mucho / no tanto la soflamerez que le meta
#
# 328 E: <risas = "E"/>  la soflamerez
# 328 I:  pero es bueno
#
# 329 E: o sea / el / el guión / ¿no? /  dices
# 329 I:  ajá  // por ejemplo / me gustó mucho mucho el guión de // ¿sí viste lo de? / ¿cómo se llama? / ¿<g>?
#
# 330 E: no
# 330 I: de M
#
# 331 E: ah / sí
# 331 I: del niño /  que nace / que también se muere
#
# 332 E:  sí / sí lo vi
# 332 I: ese me gustó / el guión me súper gustó / pero pues / las canciones que se bailaron y coreografías / ya no me gustó // y el guión yo siento que estuvo muy entendible pero ya la
#
# 333 E:  estas
# 333 I:  la  coreografía ya no <risas = "I"/> // ya no / ya no me gustó tanto
#
# 334 E: sí / no / no estuvo como tan prendido / ¿no?
# 334 I: ¿sabes qué prop <palabra_cortada/> / qué propuesta me gustó mucho? / ya en cuestión de propuesta casi no tiene / tiene mucho que ver con folclor pero es más una propuesta / lo del circo // ¿no la viste?
#
# 335 E: no / creo que no / ¿cuá <palabra_cortada/> cuál?
# 335 I: de / ya la generación que acaba de salir
#
# 336 E: no / creo que no
# 336 I: fue una propuesta donde / mezclaban folclor con circo
#
# 337 E: <ruido = "clic"/> / órale
# 337 I: entonces estuvo muy padre porque / ya en vez de de presentar Nayarit / Veracruz / y todo eso / presentaron / haz de cuenta que / iniciaba toda la historia con un payaso / que estaba en un sueño y se acuerda de lo que hacía en el circo / entonces entran a bailar este / las maringuillas / pero haciendo un / vil relajo / o sea / un circo neto / pero con folclor / y luego entran los acróbatas / pero haciendo iguanas / o cosas de esas
#
# 338 E:  órale
# 338 I:  y los  machetes / haciendo / malabares y cosas así // usando / y usaron todas las la l <palabra_cortada/> / trataron de usar los elementos que les enseñó la es <palabra_cortada/> / la escuela / en clase y en escena / en clase metieron lo de las pelotas de R y cosas así
#
# 339 E: <ruido = "clic"/> /  ¡órale!
# 339 I:  entonces <observación_complementaria= "tons"/> / les  quedó bonito / a mí me gustó / hubiera gustado ver algo de telas / bajaron telas / pero pues obviamente no <risas = "I"/>
#
# 340 E:  sí
# 340 I:  con  las chavas que no / y en folclor / pues bailaron una versión de / de La bamba / muy buena / y metieron pura técnica / puros pasos de técnica y metieron la mayoría de / de repertorios / Tabasco> / Veracruz> / Nayarit> / Sinaloa / entonces /  me gustó / hasta eso estuvo bonito
#
# 341 E: <tiempo = "59:00"/>  ¡órale! / ¿y quién  hizo ese montaje?
# 341 I: ese / lo hizo N / eh la / o sea / la dirección fue de N / pero el grupo fue / el grupo de C <risas = "I"/>
#
# 342 E: ah /  ya
# 342 I:  y  / me gustó mucho / a mí me gustó / dio mucho de qué hablar / pero pues / también / fue una propuesta /  buena
#
# 343 E:  sí  / estuvo / yo creo que ha de haber estado padre / ¿eh?
# 343 I: fue buena la / la historia // y el payaso / o sea / C fue el payaso / C aparte de tener // ba <palabra_cortada/> ser bailarín / tiene como dotes de actor / entonces / le salió súper bien su personaje de payaso // y entraban también a bailar salsa / o sea / me gustó mucho / ese proyecto / me gustó / imagínate / ese es / el que yo / uno de los que digo / <cita> con producción / ¿qué se podría hacer? </cita> / que te traigas acróbatas / que te traigas malabaristas / que traigas / folclóricos y / se puede hacer una súper producción de circo para niños y para gente // pues buena
#
# 344 E: sí es cierto
# 344 I: entonces <observación_complementaria= "tons"/> ya // esa fue la que más me gustó / de los que salieron / de la generación que salió / porque presentaron otra de / de // de c p c / así se llamó
#
# 345 E: mm
# 345 I: <ruido = "carraspeo"/> y era / una historia de // de cómo vienen de l <palabra_cortada/> sus / de su casa a la escuela> / tomaron una clase / y bailaron<alargamiento/ / prácticas y cosas así / pero ese no me gustó
#
# 346 E: mm
# 346 I: no / como que no tuvo nada más interesante que eso // así / es bueno // innovar
